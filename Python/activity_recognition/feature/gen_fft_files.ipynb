# %%
import pandas as pd
import numpy as np

from time2freq import time2freq

# %%
df = pd.read_csv('./data/processed_data/all/resample_to_50_per_act/resample_to_50.csv')

# %%
df.tail()
# Out:
#                  x           y           z  class  \
# 251295 -928.094685  163.788475  337.651526  clean
# 251296 -946.717057  177.251312  326.688697  clean
# 251297 -933.746906  167.946609  310.380039  clean
# 251298 -910.344399  154.584634  309.409075  clean
# 251299 -896.701663  143.548819  302.866383  clean
#
#                                                  seg  suspicious
# 251295  clean/庆喜/repeat_82-duration_60.csv-1584-1628       False
# 251296  clean/庆喜/repeat_82-duration_60.csv-1584-1628       False
# 251297  clean/庆喜/repeat_82-duration_60.csv-1584-1628       False
# 251298  clean/庆喜/repeat_82-duration_60.csv-1584-1628       False
# 251299  clean/庆喜/repeat_82-duration_60.csv-1584-1628       False

# %%
# %%time
new_df = time2freq(df)
# Out:
# Wall time: 23.5 s

# %%
new_df.iloc[:30]
# Out:
#             x          y          z class  \
# 0   37.126686  58.059911  54.908724  walk
# 1   35.950923  51.889219  49.264969  walk
# 2   27.620814  23.509735  25.157251  walk
# 3   12.893848  20.370314  19.715331  walk
# 4    2.914928  18.428955  19.129530  walk
# 5   -0.619681  13.980258   8.227323  walk
# 6   12.981780   6.823787  11.425384  walk
# 7   12.341063  -1.475203   5.433126  walk
# 8    1.387720  13.209907  14.573793  walk
# 9   16.759734  18.034689  18.090904  walk
# 10  13.581516  14.344292  17.520512  walk
# 11   9.641351  13.999040  13.711308  walk
# 12  10.657647  12.734313  18.226356  walk
# 13   7.609581  15.085025  19.394830  walk
# 14  10.495762  17.225998  15.966795  walk
# 15   9.556920  16.872436  10.864203  walk
# 16   6.278676  12.684021   8.987155  walk
# 17   2.314538   4.846343   5.584170  walk
# 18 -11.772840   6.748932   3.517162  walk
# 19  -3.176303   4.998056  -5.892470  walk
# 20  -5.802606  -7.890308  -4.883548  walk
# ...

# %%
new_df.to_csv('./data/processed_data/all/resample_to_50_per_act/FFT.csv', encoding='utf-8', index=False)
